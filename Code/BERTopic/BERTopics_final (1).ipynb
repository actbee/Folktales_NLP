# %% [markdown]
# # BERTopic
#
# Author: Xuedan ZOU (xuedan.zou.gr@dartmouth.edu)
#
# Date: 5/30/2022

# %% [markdown]
# ## About
#
# We tried BERTopic method to do the topic modeling as a comparision to traditional LDA method. The inputs of this algorithms are many sentences (splited from orignal texts) and the outputs are possible topics BERTopic thought and their top key words.
#
# References:
#
# [1] https://maartengr.github.io/BERTopic/index.html
#
# [2] https://github.com/MaartenGr/BERTopic (code reference)
#
# [3] Grootendorst, Maarten. "BERTopic: Neural topic modeling with a class-based TF-IDF procedure." arXiv preprint arXiv:2203.05794 (2022).

# %% [markdown]
# ## Data
#
# First try to install necessary packages and get our pre-prepared folkstories data.

# %% [markdown]
# First install and import all of the necessary packages.

# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Using cached bertopic-0.10.0-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.3.5)
# Collecting umap-learn>=0.5.0
#   Using cached umap-learn-0.5.3.tar.gz (88 kB)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.7/dist-packages (from bertopic) (4.64.0)
# Requirement already satisfied: pyyaml<6.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (3.13)
# Collecting hdbscan>=0.8.28
#   Using cached hdbscan-0.8.28.tar.gz (5.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting sentence-transformers>=0.4.1
#   Using cached sentence-transformers-2.2.0.tar.gz (79 kB)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.0.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.21.6)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (5.5.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic) (1.4.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic) (1.1.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.28->bertopic) (0.29.30)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Using cached transformers-4.19.2-py3-none-any.whl (4.2 MB)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.12.0+cu113)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.2.5)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting huggingface-hub
#   Using cached huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (4.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2019.12.20)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Using cached tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
# Collecting pyyaml<6.0
#   Using cached PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (4.11.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.0.9)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.5.0->bertopic) (0.51.2)
# Collecting pynndescent>=0.5
#   Using cached pynndescent-0.5.7.tar.gz (1.1 MB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.34.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2342149 sha256=835f0c93730ec759666673144058c155f1fca7ab78b80954d00411accc913a37
#   Stored in directory: /root/.cache/pip/wheels/6e/7a/5e/259ccc841c085fc41b99ef4a71e896b62f5161f2bc8a14c97a
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=aabd89d5e56e1129d01db4d534bdc57cdf0cbcc14da785b5f1497494873f15d5
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=5364eb4fe355af41b724741af3e0ff12be445b260151ce537da45d595c4f395b
#   Stored in directory: /root/.cache/pip/wheels/b3/52/a5/1fd9e3e76a7ab34f134c07469cd6f16e27ef3a37aeff1fe821
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.7-py3-none-any.whl size=54286 sha256=6ad639c8e43eea69dce3e9bbb750bc38777c5ee21e40ca56af07c2fa0a3849c2
#   Stored in directory: /root/.cache/pip/wheels/7f/2a/f8/7bd5dcec71bd5c669f6f574db3113513696b98f3f9b51f496c
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, pynndescent, umap-learn, sentence-transformers, hdbscan, bertopic
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed bertopic-0.10.0 hdbscan-0.8.28 huggingface-hub-0.7.0 pynndescent-0.5.7 pyyaml-5.4.1 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.19.2 umap-learn-0.5.3

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
import gdown
from bertopic import BERTopic

# %% [markdown]
# Then time to read data from Google Drive.

# %%
url = "https://drive.google.com/uc?id=1nX3c3JrEYaqaSybF8Yh4ou1C03FUkNGU"

output = 'asia.csv'
gdown.download(url, output, quiet=False)
# !unzip -j $output
df = pd.read_csv('asia.csv', header=None)
df.columns = ["numb", "country", "text"]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1nX3c3JrEYaqaSybF8Yh4ou1C03FUkNGU
# To: /content/asia.csv
# 100%|██████████| 2.31M/2.31M [00:00<00:00, 96.3MB/s]
# Archive:  asia.csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of asia.csv or
#         asia.csv.zip, and cannot find asia.csv.ZIP, period.

# %% [markdown]
# We then transfer the original texts into string list. Since we need to feed in those data into BERTopic and seperate each story as sentences will greatly help us have more data to feed in. (BERTopic regards each sentence as a seperate data)

# %%
texts= df['text'].tolist()
data = []
for story in texts:
  tex = story.split(".")
  for sentence in tex :
    data.append(sentence)
print(len(data))
# Out:
# 20910

# %% [markdown]
# ## BERTopic
#
# We then call BERTopic algorithms to finish topic modeling task given our prepared data before. For each region, we restricted the number of our topics the algorithms discovered to 30.

# %%
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True, min_topic_size=30)
topics, probs = topic_model.fit_transform(data)
# Out:
# Batches:   0%|          | 0/654 [00:00<?, ?it/s]
# 2022-05-30 15:52:41,685 - BERTopic - Transformed documents to Embeddings
# 2022-05-30 15:53:09,287 - BERTopic - Reduced dimensionality
# 2022-05-30 15:53:23,249 - BERTopic - Clustered reduced embeddings

# %%
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True,nr_topics="auto")
topics, probs = topic_model.fit_transform(data)

# %%
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True,nr_topics=30)
topics, probs = topic_model.fit_transform(data)
# Out:
# Batches:   0%|          | 0/654 [00:00<?, ?it/s]
# 2022-05-30 16:21:53,365 - BERTopic - Transformed documents to Embeddings
# 2022-05-30 16:22:27,424 - BERTopic - Reduced dimensionality
# 2022-05-30 16:25:01,423 - BERTopic - Clustered reduced embeddings
# 2022-05-30 16:25:13,264 - BERTopic - Reduced number of topics from 292 to 31

# %% [markdown]
# ## Results
#
# The results are shown as below. We can use different ways to visualize it.

# %% [markdown]
# ### Asia Result

# %%
freq = topic_model.get_topic_info(); freq.head(30)
# Out:
#     Topic  Count                                         Name
# 0      -1  15345                             -1_the_and_to_of
# 1       0    725                           0_you_will_me_your
# 2       1    442          1_fairytale_note_traditionally_tale
# 3       2    345                       2_fish_hunter_the_hook
# 4       3    268                            3_you_said_are_it
# 5       4    237                      4_sultan_the_to_sultans
# 6       5    219                  5_monkey_crab_monkeys_crabs
# 7       6    214                        6_princess_her_to_the
# 8       7    205              7_dragon_dragons_dragonking_the
# 9       8    184                         8_we_ship_island_sea
# 10      9    175  9_aponibolinayen_aponitolau_kanag_gawigawen
# 11     10    172                  10_sword_matsu_fugiwaka_his
# 12     11    166                 11_rain_clouds_cloud_thunder
# 13     12    161                            12_eat_food_he_to
# 14     13    158                        13_night_sleep_he_god
# 15     14    154                  14_tree_trees_pine_branches
# 16     15    148                     15_gold_pearls_of_silver
# 17     16    147                       16_bird_flew_the_birds
# 18     17    143                 17_rice_tikgi_ligi_silkworms
# 19     18    136           18_noureddin_persian_scheih_khacan
# 20     19    117                       19_mr_raitaro_said_you
# 21     20    117                     20_ape_yang_apes_oerlang
# 22     21    113                  21_fairy_fairies_yinglo_you
# 23     22    106                22_dschang_dynasty_liang_tang
# 24     23    106                        23_old_man_youth_good
# 25     24    105           24_aladdin_genie_magician_aladdins
# 26     25    102                   25_emperor_emperors_the_to
# 27     26    101                          26_caliph_the_of_to
# 28     27    101                           27_wu_kung_sun_ape
# 29     28    100                     28_dog_cat_whitehead_her

# %%
new_topics, new_probs = topic_model.reduce_topics(data, topics, probs, nr_topics=15)
# Out:
# 2022-05-30 16:00:09,172 - BERTopic - Reduced number of topics from 92 to 16

# %%
topic_model.visualize_barchart(top_n_topics=30)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8a7c99a6-02ae-4857-ac47-1c422dffee3c" class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a7c99a6-02ae-4857-ac47-1c422dffee3c")) {                    Plotly.newPlot(                        "8a7c99a6-02ae-4857-ac47-1c422dffee3c",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0324971993132962,0.04122281508631219,0.04422389395684757,0.04853328045383812,0.06768619713059637],"y":["to  ","your  ","me  ","will  ","you  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.12013223237938668,0.12742677173667766,0.15917439677732545,0.19393739760667503,0.19841614068011684],"y":["narrated  ","tale  ","traditionally  ","note  ","fairytale  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.03034225194475114,0.030426971664890022,0.03211825176745754,0.035128701097424615,0.06330932349252809],"y":["fisherman  ","hook  ","the  ","hunter  ","fish  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.034251773103915945,0.036168004597437214,0.03771801107748277,0.06436537060904722,0.07349046724795263],"y":["am  ","it  ","are  ","said  ","you  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.021369606746777906,0.022394815701674703,0.027708283802246682,0.035433000893929194,0.11878197129521607],"y":["that  ","sultans  ","to  ","the  ","sultan  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.03474573892407794,0.03675846912525866,0.040156374769737366,0.045599834339718065,0.12283630897623983],"y":["the  ","crabs  ","monkeys  ","crab  ","monkey  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.022780595244082567,0.030218502010396962,0.03235502498300228,0.0337591116685076,0.1056420031425205],"y":["moonlight  ","the  ","to  ","her  ","princess  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.025747782478317945,0.03752169113706214,0.03872600929176492,0.05453060408511097,0.11971236698478391],"y":["king  ","the  ","dragonking  ","dragons  ","dragon  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.026909208261662685,0.02927709002606861,0.030095895563148366,0.03536179620291715,0.039741443505296854],"y":["the  ","sea  ","island  ","ship  ","we  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.03039975903340422,0.03926468751095166,0.04120351394490176,0.07336245588784757,0.07491085812268279],"y":["and  ","gawigawen  ","kanag  ","aponitolau  ","aponibolinayen  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.030401378052569386,0.035742324398204954,0.038088265699463046,0.04549708858051597,0.12190935600499489],"y":["sadako  ","his  ","fugiwaka  ","matsu  ","sword  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.03822711447566106,0.04217616144681343,0.04444909637998466,0.04763099003419068,0.057684534121088295],"y":["the  ","thunder  ","cloud  ","clouds  ","rain  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.025181894076983263,0.026784786936278837,0.02982792148586517,0.034080537150693944,0.041331184285210966],"y":["barmecide  ","to  ","he  ","food  ","eat  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.03604912927937383,0.040733817420917404,0.0436474160156298,0.047228197614496197,0.06291777554466922],"y":["spring  "," ...

# %% [markdown]
# ## Others
#
# We then use our method to other different regions and the results are shown as the following.

# %%
url = "https://drive.google.com/uc?id=19I5XPS3rMIPAo7STn8oGl_Q498hQS1LP"
output = 'africa.csv'
gdown.download(url, output, quiet=False)
# !unzip -j $output
df = pd.read_csv('africa.csv', header=None)
df.columns = ["numb", "country", "text"]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19I5XPS3rMIPAo7STn8oGl_Q498hQS1LP
# To: /content/africa.csv
# 100%|██████████| 726k/726k [00:00<00:00, 69.0MB/s]
# Archive:  africa.csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of africa.csv or
#         africa.csv.zip, and cannot find africa.csv.ZIP, period.

# %%
texts= df['text'].tolist()
data = []
for story in texts:
  tex = story.split(".")
  for sentence in tex :
    data.append(sentence)
print(len(data))
# Out:
# 6071

# %%
topic_model_africa = BERTopic(language="english", calculate_probabilities=True, verbose=True,nr_topics=30)
topics, probs = topic_model_africa.fit_transform(data)
# Out:
# Batches:   0%|          | 0/190 [00:00<?, ?it/s]
# 2022-05-30 18:13:37,978 - BERTopic - Transformed documents to Embeddings
# 2022-05-30 18:13:54,571 - BERTopic - Reduced dimensionality
# 2022-05-30 18:13:58,319 - BERTopic - Clustered reduced embeddings
# 2022-05-30 18:14:02,652 - BERTopic - Reduced number of topics from 119 to 31

# %% [markdown]
# ### Africa Result

# %%
freq_africa = topic_model_africa.get_topic_info(); freq_africa.head(30)
# Out:
#     Topic  Count                               Name
# 0      -1   3616                   -1_the_he_and_to
# 1       0    226              0_wolf_ou_an_jackalse
# 2       1    192               1_ses_you_honey_agun
"],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.030822644979484014,0.035606984020981204,0.03736530975621779,0.037690783500855675,0.04394446129870692],"y":["their  ","and  ","were  ","the  ","they  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.053670741653179505,0.05811757582946064,0.06682218654759442,0.1008187973604308,0.11058473293815956],"y":["an  ","de  ","tree  ","leelikie  ","gum  "],"type":"bar","xaxis":"x14","yaxis":"y14"},{"m ...

# %%
url = "https://drive.google.com/uc?id=1bS7Tqz3JlGCMvrDGn4Yq2IqaGMlrHCPc"
output = 'europe.csv'
gdown.download(url, output, quiet=False)
# !unzip -j $output
df = pd.read_csv('europe.csv', header=None)
df.columns = ["numb", "country", "text"]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bS7Tqz3JlGCMvrDGn4Yq2IqaGMlrHCPc
# To: /content/europe.csv
# 100%|██████████| 3.03M/3.03M [00:00<00:00, 213MB/s]
# Archive:  europe.csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of europe.csv or
#         europe.csv.zip, and cannot find europe.csv.ZIP, period.

# %%
texts= df['text'].tolist()
data = []
for story in texts:
  tex = story.split(".")
  for sentence in tex :
    data.append(sentence)
print(len(data))
# Out:
# 24513

# %%
topic_model_europe = BERTopic(language="english", calculate_probabilities=True, verbose=True,nr_topics=30)
topics, probs = topic_model_europe.fit_transform(data)
# Out:
# Batches:   0%|          | 0/767 [00:00<?, ?it/s]
# 2022-05-30 18:24:54,050 - BERTopic - Transformed documents to Embeddings
# 2022-05-30 18:25:23,191 - BERTopic - Reduced dimensionality
# 2022-05-30 18:29:25,264 - BERTopic - Clustered reduced embeddings
# 2022-05-30 18:29:37,237 - BERTopic - Reduced number of topics from 336 to 31

# %% [markdown]
# ### Europe Result

# %%
freq_europe = topic_model_europe.get_topic_info(); freq_europe.head(30)
# Out:
#     Topic  Count                                   Name
# 0      -1  17572                       -1_the_and_to_of
# 1       0    803                0_you_naggeneen_said_do
# 2       1    574              1_ivan_tsar_tsarevich_the
# 3       2    299                     2_sea_ship_the_and
# 4       3    291    3_violette_ourson_agnella_passerose
# 5       4    289                 4_horse_the_horses_his
# 6       5    287                 5_fairy_fairies_the_of
# 7       6    273    6_blondine_bonnebiche_beauminon_her
# 8       7    235        7_bova_korolevich_drushnevna_to
# 9       8    235             8_bondeson_comp_10_sharply
# 10      9    213             9_peter_maroosia_vanya_old
# 11     10    211                10_princess_her_the_she
# 12     11    199                   11_old_woman_man_the
# 13     12    198            12_gruagach_gilla_na_cowboy
# 15     13    197                  13_fin_maol_said_bran
# 14     14    197                      14_he_him_had_was
# 16     15    190       15_yaroslav_lasarevich_tsar_thou
# 17     16    187            16_mrs_ellen_childe_rowland
# 18     17    187                  17_castle_the_of_they
# 19     18    179                    18_erin_of_king_the
# 20     19    168             19_oisin_saint_patrick_him
# 21     20    166           20_terence_kathleen_she_that
# 22     21    160                 21_king_said_asked_you
# 23     22    158                    22_gold_her_of_with
# 24     23    157            23_cat_ivanovitch_pippo_the
# 25     24    157               24_kathleen_that_she_was
# 26     25    154                25_bird_birds_the_eagle
# 27     26    151               26_forest_trees_tree_the
# 28     27    149  27_rosette_charmant_chariot_roussette
# 29     28    139       28_kings_daughter_king_daughters

# %%
topic_model_europe.visualize_barchart(top_n_topics=30)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2cc929eb-6abf-448b-b1d4-13a5b632d7f1" class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cc929eb-6abf-448b-b1d4-13a5b632d7f1")) {                    Plotly.newPlot(                        "2cc929eb-6abf-448b-b1d4-13a5b632d7f1",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.031068930108355156,0.031732805623491574,0.03337119797807158,0.044180012444216744,0.05621876009774978],"y":["john  ","do  ","said  ","naggeneen  ","you  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.02786916527222148,0.027986442425881754,0.03773013295998553,0.05071807856841785,0.0630082031390302],"y":["and  ","the  ","tsarevich  ","tsar  ","ivan  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.026801287955129222,0.026959083311753836,0.03770337305166714,0.051562588753708505,0.05789337352950945],"y":["he  ","and  ","the  ","ship  ","sea  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.03206860265061235,0.06292425690756319,0.06449831283253876,0.08103045587523242,0.15134002633341154],"y":["her  ","passerose  ","agnella  ","ourson  ","violette  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.028049866894210327,0.029922756387573524,0.03317174677004608,0.03317360206493197,0.10787922404968861],"y":["and  ","his  ","horses  ","the  ","horse  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.023723995702879676,0.027291016104720896,0.030714227943102645,0.07831745443961854,0.08973509032357768],"y":["you  ","of  ","the  ","fairies  ","fairy  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.02641595832047611,0.04463423747885758,0.05766765376340936,0.07495347534264751,0.18040633636766823],"y":["to  ","her  ","beauminon  ","bonnebiche  ","blondine  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.029356023153626995,0.032040428710676486,0.033841584397923785,0.033841584397923785,0.10781259203271365],"y":["and  ","to  ","drushnevna  ","korolevich  ","bova  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[1.1692959253617545,1.1692959253617545,1.3991837624989092,1.3991837624989092,2.48451016608009],"y":["mulvey  ","sharply  ","10  ","comp  ","bondeson  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.043139413941748764,0.06670471929765141,0.09090986128894875,0.09338817421809634,0.14998420703522078],"y":["said  ","old  ","vanya  ","maroosia  ","peter  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.02793049279082098,0.0322607527635765,0.03320784964373072,0.04324342704344647,0.12261916441222398],"y":["and  ","she  ","the  ","her  ","princess  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.029960740091871267,0.03330817306971296,0.08085401197918064,0.10699245243459311,0.17645525668115866],"y":["said  ","the  ","man  ","woman  ","old  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.049043695068144204,0.0619539281187302,0.06314534981332116,0.07082783837218089,0.08372383034220376],"y":["grakin  ","cowboy  ","na  ","gilla  ","gruagach  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.036044891398690555,0.037215226010770354,0.04004916575804454,0.04046535690690976,0.16045595994264894],"y":["conan  ","bran  ","said  ","maol  "," ...

# %%
url = "https://drive.google.com/uc?id=1WtodI_VHLKb9W9GZfOZOvzFjqOiAOkiy"
output = 'north_america_new.csv'
gdown.download(url, output, quiet=False)
# !unzip -j $output
df = pd.read_csv('north_america_new.csv', header=None)
df.columns = ["numb", "country", "text"]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1WtodI_VHLKb9W9GZfOZOvzFjqOiAOkiy
# To: /content/north_america_new.csv
# 100%|██████████| 799k/799k [00:00<00:00, 66.3MB/s]
# Archive:  north_america_new.csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of north_america_new.csv or
#         north_america_new.csv.zip, and cannot find north_america_new.csv.ZIP, period.

# %%
texts= df['text'].tolist()
data = []
for story in texts:
  tex = story.split(".")
  for sentence in tex :
    data.append(sentence)
print(len(data))
# Out:
# 7277

# %%
topic_model_northamerica = BERTopic(language="english", calculate_probabilities=True, verbose=True,nr_topics=30)
topics, probs = topic_model_northamerica.fit_transform(data)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Batches:   0%|          | 0/228 [00:00<?, ?it/s]
# 2022-06-03 21:40:28,115 - BERTopic - Transformed documents to Embeddings
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
# 
# 12     11    101                 11_bear_bears_the_and
# 13     12     93                12_chief_giants_the_to
# 14     13     88      13_wassamo_cousin_sandspirit_his
# 15     14     81                            14_oh_no__
# 16     15     80           15_meat_butcher_shop_barrel
# 17     16     72            16_deer_patkasa_rainbow_he
# 18     17     71           17_beaver_beavers_dog_giant
# 19     18     70  18_buffalo_buffaloes_braveness_woman
# 20     19     68                      19_he_was_his_to
# 21     20     68               20_fire_ashes_flames_he
# 22     21     65                21_bird_birds_flew_the
# 23     22     63               22_tree_trees_he_willow
# 24     23     63           23_sound_heard_voices_voice
# 25     24     58            24_drum_dance_beat_singers
# 26     25     54                 25_eagle_gray_red_the
# 27     26     54                  26_maidwa_and_him_of
# 28     27     53                 27_owl_owlman_and_you
# 29     28     52                     28_wolf_me_to_old

# %%
url = "https://drive.google.com/uc?id=1JT8yzb5Y0eX8unZep75f13XHhaMoAhBX"
output = 'south_america.csv'
gdown.download(url, output, quiet=False)
# !unzip -j $output
df = pd.read_csv('south_america.csv', header=None)
df.columns = ["numb", "country", "text"]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JT8yzb5Y0eX8unZep75f13XHhaMoAhBX
# To: /content/south_america.csv
# 100%|██████████| 236k/236k [00:00<00:00, 51.4MB/s]
# Archive:  south_america.csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of south_america.csv or
#         south_america.csv.zip, and cannot find south_america.csv.ZIP, period.

# %%
texts= df['text'].tolist()
data = []
for story in texts:
  tex = story.split(".")
  for sentence in tex :
    data.append(sentence)
print(len(data))
# Out:
# 2922

# %%
topic_model_southamerica = BERTopic(language="english", calculate_probabilities=True, verbose=True,nr_topics=30)
topics, probs = topic_model_southamerica.fit_transform(data)
# Out:
# Batches:   0%|          | 0/92 [00:00<?, ?it/s]
# 2022-05-30 18:39:56,672 - BERTopic - Transformed documents to Embeddings
# 2022-05-30 18:40:12,518 - BERTopic - Reduced dimensionality
# 2022-05-30 18:40:13,342 - BERTopic - Clustered reduced embeddings
# 2022-05-30 18:40:15,771 - BERTopic - Reduced number of topics from 70 to 31

# %% [markdown]
# ### South America Result

# %%
freq_southamerica = topic_model_southamerica.get_topic_info(); freq_southamerica.head(30)
# Out:
#     Topic  Count                                 Name
# 0      -1   1294                     -1_the_of_and_to
# 1       0    160                    0_you_ill_come_me
# 2       1    133                    1_he_too_away_and
# 3       2    103              2_giant_giants_the_land
# 4       3    101                3_tiger_goat_stag_the
# 5       4     86               4_rabbit_coyote_ox_the
# 6       5     65     5_dionysia_sea_serpent_labismena
# 7       6     63              6_man_father_mother_his
# 8       7     62         7_hen_white_little_quirrichi
# 9       8     55         8_bananas_peddler_wax_banana
# 10      9     52                 9_mr_mrs_jaguar_said
# 11     10     52                  10_she_her_eyes_sad
# 12     11     49             11_beetle_green_coat_rat
# 13     12     49        12_godfather_priest_bell_ring
# 14     13     49            13_prince_kingdom_his_the
# 15     14     45  14_angelita_stepmother_slippers_she
# 16     15     42               15_toad_lamb_how_lambs
# 17     16     39            16_spring_princess_her_of
# 18     17     39     17_princess_ama_beautiful_prince
# 19     18     39          18_cat_domingo_replied_tail
# 20     19     38              19_skunk_right_all_said
# 21     20     37        20_fish_fisherman_fishes_poor
# 22     21     36                21_they_city_no_their
# 23     22     32        22_horse_black_mounted_horses
# 24     23     31        23_violin_buzzard_toad_inside
# 25     24     31              24_monkey_his_waited_to
# 26     25     30            25_melon_he_thirsty_resin
# 27     26     29                               26____
# 28     27     28             27_joa_into_horse_musket
# 29     28     27       28_river_giantland_voice_giant

# %%
topic_model_southamerica.visualize_barchart(top_n_topics=30)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id
csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of australia.csv or
#         australia.csv.zip, and cannot find australia.csv.ZIP, period.

# %%
texts= df['text'].tolist()
data = []
for story in texts:
  tex = story.split(".")
  for sentence in tex :
    data.append(sentence)
print(len(data))
# Out:
# 1507

# %%
topic_model_australia = BERTopic(language="english", calculate_probabilities=True, verbose=True,nr_topics=30)
topics, probs = topic_model_australia.fit_transform(data)
# Out:
# Batches:   0%|          | 0/48 [00:00<?, ?it/s]
# 2022-05-30 18:41:22,515 - BERTopic - Transformed documents to Embeddings
# 2022-05-30 18:41:30,074 - BERTopic - Reduced dimensionality
# 2022-05-30 18:41:30,275 - BERTopic - Clustered reduced embeddings
# 2022-05-30 18:41:31,890 - BERTopic - Reduced number of topics from 36 to 31

# %% [markdown]
# ### Australia Result

# %%
freq_australia = topic_model_australia.get_topic_info(); freq_australia.head(30)
# Out:
#     Topic  Count                                        Name
# 0      -1    586                          -1_the_and_they_of
# 1       0    106                            0_she_her_his_he
# 2       1     69                      1_tree_trees_bark_they
# 3       2     54                 2_kangaroo_gwineeboo_rat_it
# 4       3     44                      3_you_my_children_will
# 5       4     44                4_water_hole_kurreahs_narran
# 6       5     37                  5_oom_their_tribe_dayoorls
# 7       6     35           6_goomblegubbon_dinewan_her_wings
# 8       7     33      7_weeoombeens_piggiebillah_fellows_emu
# 9       8     32                                   8_text___
# 10      9     32  9_deegeenboyah_mullyangah_mullyan_mullyans
# 11     10     31                        10_he_his_water_down
# 12     11     28                        11_women_we_will_are
# 14     14     27                 14_goonur_wives_husband_you
# 15     12     27       12_dogs_bougoodoogahdah_black_fellows
# 13     13     27     13_wurrunnah_wurrunnunnah_him_bunnyyarl
# 16     15     24                   15_emu_feathers_emus_they
# 17     16     24                  16_wirreenun_old_men_young
# 18     17     24                        17_ouyan_gah_gwai_ah
# 19     18     24                    18_bee_mayrah_nests_bees
# 20     19     23               19_heard_noise_voices_wailing
# 21     20     23                     20_weedah_fire_him_bird
# 22     21     22                         21_said_he_right_go
# 23     22     21       22_my_birrahlee_bunbundoolooey_forgot
# 24     23     18                     23_borah_place_the_boys
# 25     24     17                    24_fish_cooked_fire_they
# 26     25     16            25_boomerangs_throwing_threw_all
# 27     26     15                     26_answer_but_called_he
# 28     27     15                27_known_red_painted_crimson
# 29     28     15                 28_dinewan_she_dinewans_her

# %%
topic_model_australia.visualize_barchart(top_n_topics=30)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0c9746e2-4042-4b27-8ff0-cd7a92ab5d1e" class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c9746e2-4042-4b27-8ff0-cd7a92ab5d1e")) {                    Plotly.newPlot(                        "0c9746e2-4042-4b27-8ff0-cd7a92ab5d1e",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.028822098530776698,0.031067703611073815,0.03150757249960186,0.05603024021683655,0.07613294519996601],"y":["to  ","he  ","his  ","her  ","she  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.031235512947596165,0.03171816656595734,0.037160165815122534,0.054780555481215264,0.05915815187221852],"y":["whirlwind  ","they  ","bark  ","trees  ","tree  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.02941500343179595,0.03126985129374771,0.032990334533754134,0.07328498984977395,0.1385446525868747],"y":["the  ","it  ","rat  ","gwineeboo  ","kangaroo  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.05330203175691313,0.057625817657077104,0.061158504362945405,0.06386825872610864,0.14754682462321644],"y":["have  ","will  ","children  ","my  ","you  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.03412730582077609,0.04110752887645813,0.04919959903248128,0.05326217550762866,0.06890924172460555],"y":["the  ","narran  ","kurreahs  ","hole  ","water  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.03669582678782345,0.03803939829910463,0.041067264689878494,0.04120541277717471,0.08563974611583916],"y":["they  ","dayoorls  ","tribe  ","their  ","oom  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.038474158358837114,0.04582142256783866,0.049243752190139746,0.06036922059411107,0.1142804204083981],"y":["she  ","wings  ","her  ","dinewan  ","goomblegubbon  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.04237262516116814,0.04505045034042597,0.04641691207232275,0.05408582331153107,0.08307483938627473],"y":["black  ","emu  ","fellows  ","piggiebillah  ","weeoombeens  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[1e-05,1e-05,1e-05,1e-05,6.833031732786201],"y":["  ","  ","  ","  ","text  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.03555350853179288,0.04269581837241361,0.0622582103586708,0.0811488953022384,0.0815616816667875],"y":["he  ","mullyans  ","mullyan  ","mullyangah  ","deegeenboyah  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.035368786091459284,0.03955494684164348,0.03976533310551983,0.048501249697813685,0.078419702210494],"y":["him  ","down  ","water  ","his  ","he  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.060715222286487576,0.06342516113656538,0.06820723330626745,0.0722025625524058,0.08987849964988652],"y":["our  ","are  ","will  ","we  ","women  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.04006321003063734,0.04054218601074896,0.041121957358300126,0.06955183156975407,0.1058480805568804],"y":["blacks  ","fellows  ","black  ","bougoodoogahdah  ","dogs  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.033042538847259016,0.03562068572651749,0.042881763529187565,0.05597216343825932,0.11493539970251287],"y":["were  ","bunnyyarl  ","him  ","wurrunnunnah  ","wurrunnah  "],"type":"bar","xaxis":"x14"," ...

# %%
url = "https://drive.google.com/uc?id=1TLjy0f_dDjiHf-mdFRUgmEleXLOq5UmB"
output = 'all_region_data_new.csv'
gdown.download(url, output, quiet=False)
# !unzip -j $output
df = pd.read_csv('all_region_data_new.csv', header=None)
df.columns = ["numb", "country", "text"]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TLjy0f_dDjiHf-mdFRUgmEleXLOq5UmB
# To: /content/all_region_data_new.csv
# 100%|██████████| 7.26M/7.26M [00:00<00:00, 28.6MB/s]
# Archive:  all_region_data_new.csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of all_region_data_new.csv or
#         all_region_data_new.csv.zip, and cannot find all_region_data_new.csv.ZIP, period.

# %%
texts= df['text'].tolist()
data = []
for story in texts:
  if type(story) == float:
    continue
  tex = story.split(".")
  for sentence in tex :
    data.append(sentence)
print(len(data))
# Out:
# 63195

# %%
topic_model_all_regions = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics, probs = topic_model_all_regions.fit_transform(data)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Batches:   0%|          | 0/1975 [00:00<?, ?it/s]
# 2022-06-04 02:10:22,265 - BERTopic - Transformed documents to Embeddings
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
# 2022-06-04 02:12:23,071 - BERTopic - Reduced dimensionality
# 2022-06-04 03:35:37,184 - BERTopic - Clustered reduced embeddings

# %% [markdown]
# ### General Result

# %%
freq_all_regions = topic_model_all_regions.get_topic_info(); freq_all_regions.head(30)
# Out:
#     Topic  Count                                     Name
# 0      -1  28632                        -1_she_her_of_and
# 1       0   1993                          0_de_ou_ses_dat
# 2       1    889                         1_you_will_me_us
# 3       2    854                  2_ship_sea_island_shore
# 4       3    847                3_nos_mulvey_sharply_note
# 5       4    722            4_fish_fisherman_hook_fishing
# 6       5    539                    5_yes_says_said_right
# 7       6    442             6_giant_giants_jack_giantess
# 8       7    393               7_tree_trees_pine_branches
# 9       8    384   8_fairy_fairies_bienfaisante_fairyland
# 10      9    369   9_sultan_sultans_daaraaee_scheherazade
